# %%
import strax
import amstrax
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
ax = amstrax.contexts.amstrax_run10_analysis(output_folder='./strax_data') #output_folder aanpassen als je het ergens anders wilt

# %%
raw_path = "/Volumes/Extreme SSD/run10/raw/sipm" #Deze moet je zelf aanpassen

# %%
len(raw_path)+19
# Out:
# 54

# %%
raw = [r[len(raw_path)+1:len(raw_path)+19] for r in glob.glob(f'{raw_path}/*')]

# %%
failed = []
for r in raw:
    try:
        ax.make(r,'raw_records')
    except:
        failed.append(r)
# Out:
# ['190604_123729_1730',
#  '190502_093357_1724',
#  '190502_093357_1730',
#  '190502_094638_1724',
#  '190502_094638_1730',
#  '190502_112332_1724',
#  '190502_112332_1730',
#  '190502_125143_1724',
#  '190502_125143_1730',
#  '190502_135022_1724',
#  '190502_135022_1730',
#  '190506_112902_1724',
#  '190506_112902_1730',
#  '190506_113638_1724',
#  '190506_113638_1730',
#  '190506_114221_1724',
#  '190506_114221_1730',
#  '190506_114836_1724',
#  '190506_114836_1730',
#  '190506_115241_1724',
#  '190506_115241_1730',
#  '190506_115726_1724',
#  '190506_115726_1730',
#  '190506_125147_1724',
#  '190506_125147_1730',
#  '190506_144019_1724',
#  '190506_144019_1730',
#  '190506_144558_1724',
#  '190506_144558_1730',
#  '190506_144739_1724',
#  '190506_144739_1730',
#  '190506_145532_1724',
#  '190506_145532_1730',
#  '190506_145851_1724',
#  '190506_145851_1730',
#  '190506_150425_1724',
#  '190506_150425_1730',
#  '190506_151148_1724',
#  '190506_151148_1730',
#  '190506_151406_1724',
# ...
